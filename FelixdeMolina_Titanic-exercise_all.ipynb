# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
pd.read_csv('/Users/felixdemolina/2411_dsft_thebridge/2-Data-Analysis/2-Pandas/Practica/6-Titanic/data/titanic.csv')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic = pd.read_csv('/Users/felixdemolina/2411_dsft_thebridge/2-Data-Analysis/2-Pandas/Practica/6-Titanic/data/titanic.csv')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
#Método 1 - más chusquero en este caso, con groupby() + sum()
people=titanic.groupby('name')[['sex','age']].sum()
people
# Out:
#                                                   sex   age
# name
# Abbing, Mr. Anthony                              male  42.0
# Abbott, Master. Eugene Joseph                    male  13.0
# Abbott, Mr. Rossmore Edward                      male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)               female  35.0
# Abelseth, Miss. Karen Marie                    female  16.0
# ...                                               ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# van Billiard, Master. James William              male   0.0
# van Billiard, Master. Walter John                male  11.5
# van Billiard, Mr. Austin Blyler                  male  40.5
# van Melkebeke, Mr. Philemon                      male   0.0
#
# [1307 rows x 2 columns]

# %%
#Método 2 - selecciono las columnas deseadas con corchetes y .loc
people = titanic.loc[:, ['name','sex','age']]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
#Método 3 - Selecciono directamente la columnas con los corchetes. 
titanic[['name','sex','age']]
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
pd.append([titanic.head(3),titanic.tail(4)], ignore_index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 pd.append([titanic.head(3),titanic.tail(4)], ignore_index=False)
#
# AttributeError: module 'pandas' has no attribute 'append'

# %%
pd.concat([titanic.head(3),titanic.tail(4)], ignore_index=False)
# Out:
#       pclass  survived                            name     sex    age  sibsp  \
# 0          1         1   Allen, Miss. Elisabeth Walton  female  29.00      0
# 1          1         1  Allison, Master. Hudson Trevor    male   0.92      1
# 2          1         0    Allison, Miss. Helen Loraine  female   2.00      1
# 1305       3         0           Zabour, Miss. Thamine  female    NaN      1
# 1306       3         0       Zakarian, Mr. Mapriededer    male  26.50      0
# 1307       3         0             Zakarian, Mr. Ortin    male  27.00      0
# 1308       3         0              Zimmerman, Mr. Leo    male  29.00      0
#
#       parch  ticket      fare    cabin embarked boat   body  \
# 0         0   24160  211.3375       B5        S    2    NaN
# 1         2  113781  151.5500  C22 C26        S   11    NaN
# 2         2  113781  151.5500  C22 C26        S  NaN    NaN
# 1305      0    2665   14.4542      NaN        C  NaN    NaN
# ...

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
s_titanic = titanic.iloc[2:9]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 2   2.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic.iloc[39:63][::-1]
s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# 51       1         0                           Carlsson, Mr. Frans Olof
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.iloc[:,0:7]
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.iloc[:,2:5]
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.iloc[:,7:]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
# Oldest person who died in the Titanic
oldest_died = titanic[titanic['survived'] == 0].sort_values('age', ascending = False)
print(oldest_died.iloc[0])
# Out:
# pclass                         3
# survived                       0
# name         Svensson, Mr. Johan
# sex                         male
# age                         74.0
# sibsp                          0
# parch                          0
# ticket                    347060
# fare                       7.775
# cabin                        NaN
# embarked                       S
# boat                         NaN
# body                         NaN
# home.dest                    NaN
# Name: 1235, dtype: object

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
# Was he or she travelling alone or had any family travelling with?
'''Después de media hora probando cosas se me ocurre generar una columna en una copia del DataFrame original'''
titanic_alone = titanic.copy()
oldest_person_died = titanic_alone[titanic_alone['survived'] == 0].sort_values('age', ascending = False)
titanic_alone['traveling_alone'] = (titanic['sibsp'] == 0) & (titanic['parch'] == 0)
if oldest_person_died['traveling_alone'].iloc[0]:
    print(f"The oldest person who died was traveling alone in the Titanic")
else:
    print(f"The oldest person who died was not traveling alone in the Titanic")
# Out:
# The oldest person who died was traveling alone in the Titanic

# %%
'''Como extra, voy a colocar la columna traveling_alone en la nueva tabla a continuación de sibsp y parch'''
traveling_alone = titanic_alone.pop('traveling_alone') #Este método no borra definitivamente una columna, sino que lo almacena en una variable del mismo nombre para que no se pierda el contenido.
titanic_alone.insert(7, 'traveling_alone', traveling_alone)
titanic_alone
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  traveling_alone  ticket      fare    cabin  \
# ...

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %%
print(len(titanic))
# Out:
# 1309

# %%
'''Como el DataFrame Titanic tiene una longitud de 1309 filas, creo la lista hasta 1309'''
rows = np.random.randint(1309, size=5)
print(rows)
# Out:
# [837 764 353 521 217]

# %% [markdown]
# This list of numbers are random, could be different.

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = ['col1','col2','col3']
print(cols)
# Out:
# ['col1', 'col2', 'col3']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
df12 = pd.DataFrame(rows, cols)
df12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df12 = pd.DataFrame(rows, cols)
#       2 df12
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)
#     824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
# ...

# %%
'''Como me da error porque no coinciden la longitud de rows y cols, 
decido crear el DF sólo con los primeros 3 valores de rows'''
print(len(rows))
print(len(cols))
rows3 = rows[:3]
df12 = pd.DataFrame(rows3, cols)

df12
# Out:
# 5
# 3
#         0
# col1  837
# col2  764
# col3  353

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = titanic['sex'] == 'female'
print(array_fe)
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
#Rename the column "sex" to "gender"
titanic = titanic.rename(columns={'sex':'gender'})
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
# Filtrar las mujeres menores de 18 años
minor_wo = titanic[woman_titanic & (titanic['age'] < 18)]

# Contar el número de mujeres menores de 18 años
num_minor_wo = minor_wo.shape[0]

# Mostrar el resultado
print(f"Number of women younger than 18: {num_minor_wo}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 2
#       1 # Filtrar las mujeres menores de 18 años
# ----> 2 minor_wo = titanic[woman_titanic & (titanic['age'] < 18)]
# ...

# %%
minor_wo = woman_titanic[woman_titanic['age'] < 18.00]
minor_wo.shape[0]
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = woman_titanic[(woman_titanic['age'] < 18.00) & (titanic['survived'] == 0)]
dead_wo.shape[0]
# Out:
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_1574/87190945.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dead_wo = woman_titanic[(woman_titanic['age'] < 18.00) & (titanic['survived'] == 0)]
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic = titanic.dropna(how='any') # dropna con how='any' elimina filas con al menos un valor NaN en cualquier columna.
print(titanic.shape)
titanic
# Out:
# (0, 14)
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic = titanic.dropna(how='all') # dropna con how='all' elimina aquellas filas en las que todas las columnas tienen valores NaN.
print(titanic.shape)
titanic
# Out:
# (1309, 14)
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
titanic = titanic.dropna(axis=1, thresh=len(titanic) -1000)
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'embarked', 'boat', 'home.dest'],
#       dtype='object')

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
'''El ratio de missing values es el número de valores faltantes NaN dividido por el número total de filas'''
missing_values = titanic['boat'].isnull().sum()
print(missing_values)
total_rows = len(titanic)
print(total_rows)
ratio_missing_values = missing_values / total_rows
print(ratio_missing_values)
# Out:
# 823
# 1309
# 0.6287242169595111

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass').agg({'age': ['max', 'median'],'fare': ['max', 'median']})
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
by_class['age']['max']
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
by_class['fare']['median']
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: median, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = titanic.pivot_table(values='survived',index='pclass', columns='sex', aggfunc='sum' )
print(counted)
# Out:
# sex     female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %%
#Repasar las tablas dinámicas con este ejercicio y probar jugando con caracteríticas como 'embarked'

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted['total'] = counted['female'] + counted['male']
counted
# Out:
# sex     female  male  total
# pclass
# 1          139    61    200
# 2           94    25    119
# 3          106    75    181

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
counted.sort_values('total', ascending= False)
# Out:
# sex     female  male  total
# pclass
# 1          139    61    200
# 3          106    75    181
# 2           94    25    119

# %%
sort_counted_survivors = counted.sort_values('total', ascending= False)
sort_counted_survivors.iloc[0]
# Out:
# sex
# female    139
# male       61
# total     200
# Name: 1, dtype: int64

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
filt27 = titanic[(titanic['sex'] == 'female') & (titanic['pclass'] == 3) & (titanic['age'] < 30) & (titanic['survived'] == 1)]
print(filt27)
filt27.shape[0]
# Out:
#       pclass  survived                                               name  \
# 604        3         1                        Abelseth, Miss. Karen Marie
# 607        3         1          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 612        3         1                         Aks, Mrs. Sam (Leah Rosen)
# 621        3         1    Andersen-Jensen, Miss. Carla Christine Nielsine
# 625        3         1                    Andersson, Miss. Erna Alexandra
# 643        3         1                     Asplund, Miss. Lillian Gertrud
# 653        3         1                               Ayoub, Miss. Banoura
# 657        3         1                             Baclini, Miss. Eugenie
# 658        3         1                      Baclini, Miss. Helene Barbara
# 659        3         1                     Baclini, Miss. Marie Catherine
# 660        3         1              Baclini, Mrs. Solomon (Latifa Qurban)
# 661        3         1                         Badman, Miss. Emily Louisa
# ...

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
filt28 = titanic.loc[(titanic['sex'] == 'male') & (titanic['pclass'] == 1) & (titanic['age'] > 50) & (titanic['survived'] == 0)]
print(filt28)
filt28.shape[0]
# Out:
#      pclass  survived                            name   sex   age  sibsp  \
# 9         1         0         Artagaveytia, Mr. Ramon  male  71.0      0
# 81        1         0    Crosby, Capt. Edward Gifford  male  70.0      1
# 115       1         0               Fortune, Mr. Mark  male  64.0      1
# 135       1         0       Goldschmidt, Mr. George B  male  71.0      0
# 154       1         0      Hays, Mr. Charles Melville  male  55.0      1
# 158       1         0     Hipkins, Mr. William Edward  male  55.0      0
# 174       1         0         Kent, Mr. Edward Austin  male  58.0      0
# 201       1         0         McCarthy, Mr. Timothy J  male  54.0      0
# 205       1         0       Millet, Mr. Francis Davis  male  65.0      0
# 210       1         0      Molson, Mr. Harry Markland  male  55.0      0
# 215       1         0      Newell, Mr. Arthur Webster  male  58.0      0
# 217       1         0    Nicholson, Mr. Arthur Ernest  male  64.0      0
# ...

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
unique_names = titanic['name'].unique()
print(unique_names)
unique_names.shape[0]
# Out:
# ['Allen, Miss. Elisabeth Walton' 'Allison, Master. Hudson Trevor'
#  'Allison, Miss. Helen Loraine' ... 'Zakarian, Mr. Mapriededer'
#  'Zakarian, Mr. Ortin' 'Zimmerman, Mr. Leo']
# 1307

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
name_counts = titanic['name'].value_counts()
repeated_names = name_counts[name_counts>1]
print(repeated_names)
# Out:
# name
# Kelly, Mr. James        2
# Connolly, Miss. Kate    2
# Name: count, dtype: int64

# %%
#Cuando repase, probar a resolver con la función .duplicated()

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
plt.figure(figsize=(10,5))
plt.hist(titanic['age'].dropna())

plt.title('Age distribution in the Titanic')
plt.xlabel('Age')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
plt.figure(figsize=(10,5))
plt.hist(titanic['age'].dropna())

plt.title('Gender distribution in the Titanic')
plt.xlabel('Gender')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=titanic, x='sex')

plt.title('Gender distribution in the Titanic')
plt.xlabel('Gender')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
sns.catplot(data=titanic, x='sex', hue='survived', kind='count', palette='husl')

plt.title('Survivors by gendre in the Titanic')
plt.xlabel('Gendre')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
not_survived = titanic[titanic['survived'] == 0]

sns.kdeplot(data=not_survived['age'], color = 'red', label='Not Survived', fill=True)

plt.title('Age distribution of people who did not survive the Titanic')
plt.xlabel('Age')
plt.ylabel('Not Survived Density')

plt.show()
